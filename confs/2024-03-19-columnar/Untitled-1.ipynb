# %%
import sqlalchemy
engine = sqlalchemy.create_engine("monetdb+pymonetdb://monetdb:monetdb@172.24.112.1:50000")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import sqlalchemy
#       2 engine = sqlalchemy.create_engine("monetdb+pymonetdb://monetdb:monetdb@172.24.112.1:50000")
#
# File /mnt/c/Users/Andy/Documents/docs/@archive/2024/bd-in-data-science/confs/2024-03-19-columnar/.venv-ubuntu/lib/python3.10/site-packages/sqlalchemy/__init__.py:9
#       1 # sqlalchemy/__init__.py
#       2 # Copyright (C) 2005-2017 the SQLAlchemy authors and contributors
#       3 # <see AUTHORS file>
#       4 #
#       5 # This module is part of SQLAlchemy and is released under
#       6 # the MIT License: http://www.opensource.org/licenses/mit-license.php
# ----> 9 from .sql import (
#      10     alias,
#      11     all_,
#      12     and_,
#      13     any_,
#      14     asc,
#      15     between,
#      16     bindparam,
#      17     case,
#      18     cast,
# ...

# %%
# %reload_ext sql
# %sql monetdb://monetdb:monetdb@localhost:50000

# %%
# %sql USE demo;
